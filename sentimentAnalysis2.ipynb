# %% [markdown]
# <a href="https://colab.research.google.com/github/fawaaazi/test/blob/main/sentimentAnalysis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bert
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bert: filename=bert-2.2.0-py3-none-any.whl size=3744 sha256=e935679f2ff1b031701c36c3e6d14568f4c793289092e4cffad04faf4af9efb3
#   Stored in directory: /root/.cache/pip/wheels/55/82/8d/a9bad0b8280eb858aa3dcb4e617ee5a1653fdeb239e1e8c3fe
# ...
#   Created wheel for erlastic: filename=erlastic-2.0.0-py3-none-any.whl size=6780 sha256=9319f8c963d9bd4d709179fc66fe94c2b05af1e1e0e74f3367da5b21f8d726d5
#   Stored in directory: /root/.cache/pip/wheels/63/ea/24/ab8ff86604f1a87ca69a06af89bb7e080a5e064fbf5581423f
# Successfully built bert erlastic
# ...

# %%
# !pip install transformers
from transformers import pipeline
classifer = pipeline("sentiment-analysis")
# Out:
# ...
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
sentiment = classifer("I am very happy today")
print(sentiment)
sentiment = classifer("In a world so utterly unburdened by any notion of gloom, where not a single star dares to hide behind clouds that refuse to dampen our spirits, I find myself blissfully deprived of any reason to frown as the sun, in its mercilessly relentless shine, bombards my face with warmth that I would never escape even if I could, and the birds, those insufferably cheerful creatures, won’t stop reminding me that my dreams are far too loud to ever let me sleep in peace, while the trees, rooted in a soil that’s so incapable of nurturing despair, stretch their branches like open arms, denying any passing wind a chance to steal away the whispers of joy that swirl around me like invisible confetti, and somewhere in this beautifully chaotic refusal of misery, I can’t help but marvel at the neighbors whose daily arguments about whose roses bloom brighter have become the least tolerable form of entertainment, especially when they pretend they’re angry while secretly boasting that their gardens have become the envy of bees and butterflies who swarm like tiny winged approval ratings, so I walk past their picket fences and breathe in the scent of competition disguised as blossoms, knowing full well that my own patch of dandelions, so painfully resistant to being tamed, are, in their stubborn wildness, a crown of gold to my otherwise unremarkably flawless lawn, where each blade of grass dares not bend under the weight of disappointment, because disappointment itself has been thoroughly banished from this plot of earth that smiles back at me every morning when the dew, that uninvited guest of dawn, insists on lingering like pearls only to vanish under the caress of a sunbeam that destroys shadows with a grace that borders on tyranny, and somewhere between the chirps of crickets that refuse to be quiet even when the moon is kind enough to bathe them in borrowed silver, I find it utterly impossible to muster a single complaint about how the night air wraps around me like a blanket woven from the threads of every laugh I’ve ever stifled, which now echo back in the hoots of a lone owl who, with the most sarcastic glance I’ve ever received from a bird, seems to say, “Oh, you poor soul, suffering under all this unbearable happiness ")
print(sentiment)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998797178268433}]
# [{'label': 'POSITIVE', 'score': 0.8614946007728577}]

# %%
review_sentiment = classifer("Title: Finally, shoes that ruin my excuses for sitting down.Wow. Just wow. I bought these shoes fully expecting them to disappoint me like every other overpriced foot prison I’ve owned — but no, these traitorous lumps of fabric and rubber had the audacity to be comfortable. Seriously, how dare they.")
print(review_sentiment)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9962206482887268}]

# %%
pipeline("text-classification", model="mrm8488/t5-base-finetuned-sarcasm-twitter")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Some weights of T5ForSequenceClassification were not initialized from the model checkpoint at mrm8488/t5-base-finetuned-sarcasm-twitter and are newly initialized: ['classification_head.dense.bias', 'classification_head.dense.weight', 'classification_head.out_proj.bias', 'classification_head.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ...

# %%
classifier = pipeline("text-classification", model="mrm8488/t5-base-finetuned-sarcasm-twitter")
# Out:
# Some weights of T5ForSequenceClassification were not initialized from the model checkpoint at mrm8488/t5-base-finetuned-sarcasm-twitter and are newly initialized: ['classification_head.dense.bias', 'classification_head.dense.weight', 'classification_head.out_proj.bias', 'classification_head.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu

# %%
review_sentiment = classifier("Title: Finally, shoes that ruin my excuses for sitting down.Wow. Just wow. I bought these shoes fully expecting them to disappoint me like every other overpriced foot prison I’ve owned — but no, these traitorous lumps of fabric and rubber had the audacity to be comfortable. Seriously, how dare they.")
print(review_sentiment)
# Out:
# [{'label': 'LABEL_1', 'score': 0.5700568556785583}]

# %%
setiment = classifer("Wow, I just love it when my shoes squeak with every step — free soundtrack to my life!")
print(sentiment)
# Out:
# [{'label': 'POSITIVE', 'score': 0.8614946007728577}]

# %%
sentiment = classifier("Wow, I just love it when my shoes squeak with every step — free soundtrack to my life!")
print(sentiment)
# Out:
# [{'label': 'LABEL_1', 'score': 0.5387054085731506}]

# %%
setiment = classifier("Perfect, spilled coffee on my shirt right before the big presentation — I really needed that splash of character.")
print(sentiment)
# Out:
# [{'label': 'LABEL_1', 'score': 0.5387054085731506}]
